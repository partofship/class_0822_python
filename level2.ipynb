# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : Chapter05 ~ 08 문제풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
#
# Chapter05~08의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 코딩나라는 파이썬 문법을 통해 타이틀을 바꿔주면 신분을 변경할 수 있습니다.
# 평민이 왕의 타이틀을 뻇으려고 합니다.
# 평민의 신분상승 도와주세요 ! 그리고 출력으로 확인시켜주세요 !
#
# <br>
# 출력 예)
#
# 평민은 이제 '왕'
#
# 왕은 이제 '평민'
# <br>

# %%
title_king = '왕'
title_low = '평민'
print(f"평민은 이제 {title_king}")
print(f"왕은 이제 {title_low}")
# Out:
# 평민은 이제 왕
# 왕은 이제 평민

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 꿈에서 숫자가 보였습니다.
#
# 바로 로또를 사려고 하는데 앗 숫자가 너무 길어요 !
#
# 정수부분만 잘라서 로또 번호를 골라보기로 했습니다.
#
# 122211170788345.273782741828653689149813 정수 부분만 출력해주세요.
#
#
# <br>

# %%
x = 122211170788345.273782741828653689149813
print(int(x))
# Out:
# 122211170788345

# %% [markdown]
# <br>
#
# __[문제3]__
#
#
# sentence 변수를 할당하고, 양쪽 공백을 제거한 후 출력해주세요 !
#
# <br>
#
# __sentence = " Hello World!  "__

# %%
sentence = " Hellow World! "
exp_result = sentence[1:14]
print(exp_result)
# Out:
# Hellow World!

# %% [markdown]
# <br>__[문제4]__
#
# 산만이가 집중력 테스트를 하기로 합니다.
#
# 아주아주 긴 문자열이 있는데 여기에서 s의 횟수를 세보라고 합니다.
#
# 파이썬을 배운 산만이에게는 꼼수가 있습니다.
#
# 어떤 꼼수를 사용했을지 코드로 작성하고, 출력해주세요 !
#
# <br>
#
# __str = "sdsdsddddddsdsssdssssdssssdsdssssssssssdsdsdsdsdssssdsdsssdssssdssssdsdssdsssdssssdssssdsdssdsssdssssdssssdsdssdsssdssssdssssdsdss"__

# %%
contest_str = "sdsdsddddddsdsssdssssdssssdsdssssssssssdsdsdsdsdssssdsdsssdssssdssssdsdssdsssdssssdssssdsdssdsssdssssdssssdsdssdsssdssssdssssdsdss"
print(contest_str.count("s"))
# Out:
# 91

# %% [markdown]
# __[문제5]__
#
#
# 변수 data에 "apple, banana, cherry"를 할당하고, 이를 쉼표 기준으로 분리하여 출력해주세요 !

# %%
data = "apple, banana, cherry"
result_data= data.split(",")
print(result_data)
# Out:
# ['apple', ' banana', ' cherry']

# %% [markdown]
# __[문제6]__
#
#
# 오즈 코딩 스쿨 백엔드 8기 과정에 참여한 수강생 중 5명의 수강생이 자율적으로 스터디 그룹을 결성했습니다.
#
# 스터디 그룹 내에는 한 주간 배운 내용으로 매주 쪽지 시험을 보는 룰이 있습니다.
#
# 이 쪽지 시험의 평균이 70점이 넘으면 주말 스터디는 없습니다.
#
# 주말 스터디의 여부를 True 또는 False로 출력해주세요.
#
# <br>
# A: 70, B: 75, C: 50, D: 80, E: 60

# %%
student_score_list = [70, 75, 50, 80, 60]
WS_YN = sum(student_score_list)/len(student_score_list) > 70
print(sum(student_score_list)/len(student_score_list), WS_YN)
# Out:
# 67.0 False
